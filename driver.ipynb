# %%
from job_skill import run
from job_skill import openai_api as oa

# %%
run.main()
# Out:
# ######Job Description number###### 1
# ######Job Description number###### 2
# ######Job Description number###### 3

# %%
import pandas as pd
from job_skill import job_viz as jv

jobs = pd.read_csv("jobs.csv")
jobs
# Out:
#    Job URL  Job Title  Job Location  \
# 0      NaN        NaN           NaN
# 1      NaN        NaN           NaN
# 2      NaN        NaN           NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Skills_and_Percentage  \
# 0                                                                                                                                                                                                                                                                                                                                                             [('Data Profiling', '10'), ('Data Cleaning', '10'), ('Data Mining', '10'), ('Technical Documentation', '10'), ('Time-Series Analysis', '10'), ('Digital Signal Processing', '10'), ('Predictive Maintenance', '10'), ('Big Data Technologies', '10'), ('Programming Language', '10'), ('AI/Data Science Algorithms', '10'), ('Agile Development', '10'), ('English Communications', '10'), ('French Communications', '10')]
# 1  [("                Bachelor's Degree or Post-Secondary Education in Business, Information Systems or a Relevant Field", '10'), ('                Completion of a Recognized Business Analysis Program', '10'), ('                3+ Years of Experience as a Business Analyst', '10'), ('                Experience with Working in Agile/Waterfall Methodologies', '10'), ('                Familiarity with the Data & Analytics Product Lifecycle', '10'), ('                High Level of Analytical and Critical Thinking', '10'), ('                Solid Understanding of Data Models (ERDs)', '10'), ('                Strong SQL Knowledge', '10'), ('                Experience Working in Power Automate', '10'), ('                Excellent Interpersonal Skills', '10')]
# 2                                                                                                                                                                                                                                                                                                                             [('                Product Management', '20'), ('                Technical Project Management', '20'), ('                Influencing and Defining Go-to-Market Processes', '10'), ('                Learning and Sharing Best Practices', '10'), ('                Resolving Challenges', '10'), ('                Showcasing Advanced Technology', '10'), ('                Clear Communication', '10'), ('                Working with Customers', '10')]
#
#         Programming Languages  \
# 0  ['Java, C#, Ruby, Python']
# 1     ['SQL, Power Automate']
# 2                    ['None']
#
#                                                            Tools  \
# 0  ['Azure/AWS, MLOps, Data Management and Analytics Platforms']
# 1                                                       ['JIRA']
# 2                                                ['Slack, Zoom']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                        Technical Skills
# 0                                                                                                                                 ['Machine Learning, Artificial Intelligence, Data Science, Time-Series Analysis, Digital Signal Processing, Predictive Maintenance, Reliability Engineering, Data Profiling, Data Cleaning, Data Mining, Technical Documentation, Big Data Technologies, Statistics, Agile Development Environment.']
# 1                                                                                                                                                                                                                         ['Business Analysis, Agile/Waterfall Methodologies, Data Modeling (ERDs), Interpersonal Skills, Critical Thinking, Organizational and Prioritization Skills, Problem Solving, Flexibility and Adaptability.']
# 2  ['Product management, Technical project management, Go-to-market process, Complex software applications and workflow methodologies, Writing clear instructions, Resolving hard challenges, Delivering responsive customer service, Setting strategy, Capturing ideas, Prioritizing work, Creating visual roadmaps, Integrating Aha! software with existing tools, Testing new product functionality, Mentoring newer team members.']

# %%
jobs_df = pd.read_csv('jobs.csv')
# jobs_df = oa.call_api(df1)

# # #parse the jobs_df to clean columns and make ready for visualization
lang = jv.parse_df(jobs_df, 'Programming Languages')
tools = jv.parse_df(jobs_df, 'Tools')

# #call function to return visual for tools and programming languages
jv.visualize_info(lang, tools)
# Out:
# c:\Users\avish\AppData\Local\Programs\Python\Python39\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.VConcatChart(...)

# %%
# #call function to return visual for location distribution
jv.visualize_location(jobs_df, 'Job Location')
# Out:
# No locations available to build chart!
# False

# %%
interview = pd.read_csv("interview.csv")
interview
# Out:
#     Job Number  \
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# 5            2
# 6            2
# 7            2
# 8            2
# 9            2
# 10           3
# 11           3
# 12           3
# 13           3
# 14           3
#
#                                                                                          Questions  \
# 0                   What experience do you have with Machine Learning and Artificial Intelligence?
# 1                                    How have you used Time-Series Analysis in your past projects?
# 2                                 What techniques do you use for Data Profiling and Data Cleaning?
# 3                                                 What Big Data Technologies have you worked with?
# 4                                         How familiar are you with Agile Development Environment?
# 5                           How have you used Agile/Waterfall Methodologies in your past projects?
# 6                                  Describe a data modeling project you have worked on in the past
# 7                                      How do you use critical thinking to solve complex problems?
# 8                                                How do you prioritize tasks and manage your time?
# 9   What strategies do you use to remain flexible and adaptable in a rapidly changing environment?
# 10                          How would you prioritize a complex project with multiple stakeholders?
# 11                                 How do you ensure customer service is responsive and effective?
# 12                                     What strategies have you used to capture and develop ideas?
# 13                         How have you successfully integrated Aha! software with existing tools?
# 14                              What techniques do you use to mentor and train newer team members?
#
#                                                                                                                                                                                                                                                                                                             AI Suggested Response
# 0                                                                                                                                                                I have experience with Machine Learning and Artificial Intelligence, including working with supervised and unsupervised learning techniques and neural networks.
# 1                                                                                                                                                                                                   I have used Time-Series Analysis in a previous project to understand patterns in customer data and develop predictive models.
# 2                                                                                                                                   For Data Profiling and Data Cleaning, I typically use methods such as Exploratory Data Analysis, data visualization, data association, data benchmarking and anomaly detection, among others.
# 3                                                                                                                                                                                                                                                   I have worked with Big Data Technologies such as Hadoop, Spark and MapReduce.
# 4                                                                                                                                                                                                I am quite familiar with Agile Development Environment and have experience applying the Agile approach to data science projects.
# 5                                                          I have experience with both Agile and Waterfall Methodologies, and can tailor my approach to a project depending on the size and complexity. For example, on large projects I typically lean towards Waterfall, while for smaller projects I prefer an Agile approach.
# 6                                                                          I have previously worked on a data modeling project for a large bank in order to create a predictive model for the business’s acquisition strategy. I used a variety of machine learning algorithms and data analysis techniques to develop the model.
# 7                                                         To solve complex problems, I use a combination of logical and analytical reasoning, drawing on past experience and data to identify potential solutions. I also prefer to take an iterative approach, gradually refining my solution until I reach the desired outcome.
# 8   When prioritizing tasks, I start by making a list of immediate and long-term goals, and then use available resources and timelines to determine the order of priority. I also use productivity tools such as to-do lists, project timelines and time tracking software to help manage my workload and keep track of progress.
# 9     I use a variety of strategies to remain flexible and adaptable in a rapidly changing environment. For example, I stay up to date on emerging technologies and new approaches, I stay open to feedback from colleagues, and I use adaptive problem-solving techniques to quickly identify and address unexpected challenges.
# 10                                                   When prioritizing a complex project with multiple stakeholders, I use the SMART technique. I define the overall goal, determine what resources are necessary, identify potential obstacles, set specific criteria for success, and create a timeline to meet specific goals.
# 11                                                                                To ensure customer service is responsive and effective, I train team members in customer service best practices and use customer service software to measure response times. I also look at customer feedback to identify areas of improvement.
# 12                                                                                                                                                             I use brainstorming, research, and collaboration to capture and develop ideas. I also keep a running list of any potential solutions and evaluate their viability.
# 13                                                           I have successfully integrated Aha! software with existing tools by mapping out processes and incorporating the software into daily operations. I also make sure that team members are trained on the new tool and have the necessary resources to use the software.
# 14                               To mentor and train newer team members, I use tutorials, video demonstration, hands-on practice sessions, and role-playing scenarios so that they can learn how to properly use tools and techniques. I also provide regular feedback and guidance to ensure that they are meeting expectations.
